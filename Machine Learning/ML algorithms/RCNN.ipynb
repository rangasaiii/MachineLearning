# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2
import numpy as np
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

# %%
# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 0s 0us/step

# %%
# Load and preprocess the image
img_path = '/content/drive/MyDrive/elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# Get predictions
predictions = model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 325ms/step

# %%
# Decode predictions
decoded_predictions = decode_predictions(predictions)

# %%
# Display the top predictions
for i, (imagenet_id, label, score) in enumerate(decoded_predictions[0]):
    print(f"{i + 1}: {label} ({score:.2f})")
# Out:
# 1: Indian_elephant (0.85)
# 2: tusker (0.08)
# 3: African_elephant (0.07)
# 4: Arabian_camel (0.00)
# 5: water_buffalo (0.00)

# %%
# Display the image with bounding boxes
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Draw bounding boxes on the image
for _, label, score in decoded_predictions[0]:
    if score > 0.5:  # Adjust the threshold based on your needs
        print(f"Object: {label}, Score: {score}")
        cv2.putText(
            img,
            f"{label}: {score:.2f}",
            (50, 50),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (255, 0, 0),
            2,
            cv2.LINE_AA,
        )
# Out:
# Object: Indian_elephant, Score: 0.8485648036003113

# %%
# Display the image with bounding boxes
import matplotlib.pyplot as plt  # Import the necessary module
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
from tensorflow.keras.preprocessing import image

# %%
model=ResNet50(weights="imagenet")

# %%
img_path="/content/ee.jpeg"
img=image.load_img(img_path,target_size=(224,224))
img_array=image.img_to_array(img)
img_arrray=np.expand_dims(img_array,axis=0)
img_array=preprocess_input(img_array)

# %%
# Load and preprocess the image
img_path ="/content/ee.jpeg"
img = image.load_img(img_path,target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
predictions=model.predict(img_array)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
decoder=decode_predictions(predictions)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step

# %%
for i,(imagenet_id,label,score) in enumerate(decoder[0]):
  print(f"{i+1}: {label}: ({score:.2f})")
# Out:
# 1: Indian_elephant: (0.81)
# 2: tusker: (0.18)
# 3: African_elephant: (0.00)
# 4: Great_Dane: (0.00)
# 5: Rhodesian_ridgeback: (0.00)

# %%
img=cv2.imread(img_path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
for _,label,score in decoder[0]:
  if score>0.5:
    print(f"Object:{label},score:{score}")
    cv2.putText(
        img,
        f"{label}:{score:.2f}",
        (50,50),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (255,0,0),
        2,
        cv2.LINE_AA
    )
# Out:
# Object:Indian_elephant,score:0.8120911717414856

# %%
# Display the image with bounding boxes
import matplotlib.pyplot as plt  # Import the necessary module
plt.imshow(img)
plt.axis('off')
plt.show()
